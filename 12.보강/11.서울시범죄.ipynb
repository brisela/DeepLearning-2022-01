# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
crime = pd.read_csv('data/서울시 5대범죄 발생현황(2019).tsv', sep='\t')
crime.head()
# Out:
#      기간  자치구       합계    합계.1   살인 살인.1   강도 강도.1 강간강제추행 강간강제추행.1      절도  \
# 0    기간  자치구       발생      검거   발생   검거   발생   검거     발생       검거      발생
# 1  2019   합계  103,668  74,805  136  128  136  133  6,469    6,007  42,204
# 2  2019  종로구    3,846   4,117    4    5    7    8    238    1,143   1,515
# 3  2019   중구    4,327   2,804    2    1    6    5    195      115   2,202
# 4  2019  용산구    3,313   2,611    3    3    3    4    272      237     999
#
#      절도.1      폭력    폭력.1
# 0      검거      발생      검거
# 1  21,284  54,723  47,253
# 2   1,069   2,082   1,892
# 3   1,050   1,922   1,633
# 4     544   2,036   1,823

# %%
crime.drop([0], inplace=True) # 첫번째 행 삭제(합계행)
crime.drop(columns=['기간'], inplace=True)   # 기간 열 삭제
crime.head(3)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-7adcb7f92ca4> in <module>
# ----> 1 crime.drop([0], inplace=True) # 첫번째 행 삭제(합계행)
#       2 crime.drop(columns=['기간'], inplace=True)   # 기간 열 삭제
#       3 crime.head(3)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
# ...
